# %% [markdown]
# # CS5644 Capstone Project
# ## NY Accident analysis
# Members
# * Jordan Alam
# * David Alger
# * Johann Ruiz

# %%
# imports
import pandas as pd

# %%
# data imports
crashes = pd.read_csv('./data/Motor_Vehicle_Collisions_-_Crashes_20241103.csv', index_col=0, low_memory=False)
persons = pd.read_csv('./data/Motor_Vehicle_Collisions_-_Person_20241103.csv', index_col=0, low_memory=False)
vehicles = pd.read_csv('./data/Motor_Vehicle_Collisions_-_Vehicles_20241103.csv', index_col=0, low_memory=False)

# %%
crashes
# Out:
#            CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# CRASH DATE
# 09/11/2021       2:39       NaN      NaN        NaN        NaN
# 03/26/2022      11:45       NaN      NaN        NaN        NaN
# 06/29/2022       6:55       NaN      NaN        NaN        NaN
# 09/11/2021       9:35  BROOKLYN    11208  40.667202 -73.866500
# 12/14/2021       8:13  BROOKLYN    11233  40.683304 -73.917274
# ...               ...       ...      ...        ...        ...
# 08/06/2024      20:39       NaN      NaN        NaN        NaN
# 08/06/2024      12:00    QUEENS    11001        NaN        NaN
# 07/29/2024       2:30       NaN      NaN  40.723442 -73.938990
# 08/02/2024      15:48       NaN      NaN        NaN        NaN
# 08/06/2024      12:46       NaN      NaN        NaN        NaN
#
#                            LOCATION              ON STREET NAME  \
# CRASH DATE
# 09/11/2021                      NaN       WHITESTONE EXPRESSWAY
# ...

# %%
persons
# Out:
#            COLLISION_ID  CRASH_DATE CRASH_TIME  \
# UNIQUE_ID
# 10249006        4229554  10/26/2019       9:43
# 10255054        4230587  10/25/2019      15:15
# 10253177        4230550  10/26/2019      17:55
# 6650180         3565527  11/21/2016      13:05
# 10255516        4231168  10/25/2019      11:16
# ...                 ...         ...        ...
# 13193398        4767904  10/29/2024      15:32
# 13193338        4767864  10/29/2024      17:00
# 13192746        4767688  10/28/2024       0:36
# 13192873        4767781  10/24/2024      16:10
# 13192377        4767577  10/29/2024      12:57
#
#                                       PERSON_ID PERSON_TYPE PERSON_INJURY  \
# UNIQUE_ID
# 10249006   31aa2bc0-f545-444f-8cdb-f1cb5cf00b89    Occupant   Unspecified
# 10255054   4629e500-a73e-48dc-b8fb-53124d124b80    Occupant   Unspecified
# 10253177   ae48c136-1383-45db-83f4-2a5eecfb7cff    Occupant   Unspecified
# 6650180                                 2782525    Occupant   Unspecified
# ...

# %%
vehicles
# Out:
#            COLLISION_ID  CRASH_DATE CRASH_TIME  \
# UNIQUE_ID
# 10385780         100201  09/07/2012       9:03
# 19140702        4213082  09/23/2019       8:15
# 14887647        3307608  10/02/2015      17:18
# 14889754        3308693  10/04/2015      20:34
# 14400270         297666  04/25/2013      21:15
# ...                 ...         ...        ...
# 20774561        4767779  10/27/2024      15:16
# 20774656        4767855  10/28/2024       7:45
# 20773672        4767169  10/29/2024       4:25
# 20774412        4767800  10/24/2024      14:42
# 20774394        4767691  10/28/2024       8:37
#
#                                      VEHICLE_ID STATE_REGISTRATION  \
# UNIQUE_ID
# 10385780                                      1                 NY
# 19140702   0553ab4d-9500-4cba-8d98-f4d7f89d5856                 NY
# 14887647                                      2                 NY
# 14889754                                      1                 NY
# ...

# %%
# initial data manipulation
